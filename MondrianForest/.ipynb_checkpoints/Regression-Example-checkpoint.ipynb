# %% [markdown]
# ### Its doing something right
#
# It's working, the noise is a bit odd. Will investigate
# the performance soon.
#
# Sometimes the MF regressor creates massive noise in the predictions

# %%
using Plots
using MLMetrics;
include("Mondrian_Forest_Regressor.jl")
# Out:
# LoadError: LoadError: LoadError: invalid redefinition of constant Mondrian_Node
# while loading /home/harvey/Group Project/warwick-rsg/MondrianForest/Mondrian_Tree.jl, in expression starting on line 9
# while loading /home/harvey/Group Project/warwick-rsg/MondrianForest/Mondrian_Tree_Regression.jl, in expression starting on line 2
# while loading /home/harvey/Group Project/warwick-rsg/MondrianForest/Mondrian_Forest_Regressor.jl, in expression starting on line 1
#
# Stacktrace:
#  [1] include_from_node1(::String) at ./loading.jl:576
#  [2] include(::String) at ./sysimg.jl:14
#  [3] include_from_node1(::String) at ./loading.jl:576
#  [4] include(::String) at ./sysimg.jl:14
#  [5] include_from_node1(::String) at ./loading.jl:576
#  [6] include(::String) at ./sysimg.jl:14
#  [7] include_string(::String, ::String) at ./loading.jl:522

# %%
X = collect(linspace(1,16,1000))
Y = X+sin.(X)

MT = Mondrian_Tree_Regressor()
train!(MT, X, Y, 1e3, 10);

y = predict!(MT,X);

err = round(mean_squared_error(Y,y),6)

p1 = plot(X,Y, label="Truth", color="blue");
p2 = plot(X,y, label="Mondrian Tree  \nRegression",color="red");
plot(p1,p2,legend=:topleft)
# Out:
# 0.004218496332819344

# %%
X = collect(linspace(1,16,1000))
Y = X+sin.(X)

MF = Mondrian_Forest_Regressor()
train!(MF, X, Y, 1e6, 10);

y = predict!(MF,X);

err = round(mean_squared_error(Y,y),6)

p1 = plot(X,Y, label="Truth", color="blue");
p2 = plot(X,y, label="Mondrian Forest  \nRegression",color="red");
title!("Mean Square Error $err")


plot(p1,p2,legend=:topleft)

# %%
function predict!{X<:Array{<: AbstractFloat} where N,}(
                  MF::Mondrian_Forest_Regressor,
                  Data::X)
    pred = zeros(MF.n_trees,size(Data,1))
    println("T")
    for item in enumerate(MF.Trees)
        println("K")
        pred[item[1],:] = predict!(item[2], Data)
    end
    p = []
    for i in 1:size(Data,1)
        push!(p, mean(pred[:,i]))
    end
    return p
end
# Out:
# predict! (generic function with 3 methods)

# %%
function predict!{X<:Array{<: AbstractFloat} where N,}(
                  MF::Mondrian_Forest_Regressor,
                  Data::X)
    
    pred = zeros(MF.n_trees,size(Data,1))

    for item in enumerate(MF.Trees)
        pred[item[1],:] = predict!(item[2], Data)
    end
    p = []
    for i in 1:size(Data,1)
        push!(p, mean(pred[:,i]))
    end
    return p
end
# Out:
# predict! (generic function with 3 methods)
