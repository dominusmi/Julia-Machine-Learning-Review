# %%
using Plots
plotly()
# Out:
# Plots.PlotlyBackend()

# %%
include("LocalOutlierFactor.jl")
# Out:
# local_reachability_density

# %%
data = randn(10^3,2);
outliers = rand([-5,5],50,2)
dayta = vcat(data,outliers)
is_outlier = fit_predict(data);
scatter(data[:,1],data[:,2],group = is_outlier, title = "Local Outlier Factor")
# Out:
# <script src="file:///home/mathsys2/.julia/v0.6/Plots/src/backends/../../deps/plotly-latest.min.js"></script>    <div id="8f38e8e3-1792-41be-a531-8d91b0866466" style="width:600px;height:400px;"></div>
#     <script>
#     PLOT = document.getElementById('8f38e8e3-1792-41be-a531-8d91b0866466');
# ...
